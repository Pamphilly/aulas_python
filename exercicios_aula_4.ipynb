# %% [markdown]
# Exercicios A

# %%
idade = int (input("Digite sua idade: "))
carteira = input("Tem carteira de motorista? (sim/nao): ")

if idade >= 18 and carteira == "sim":
    print("Pode dirigir")

else: 
    print("Nao pode dirigir")
# Out:
# Digite sua idade:  17
# Tem carteira de motorista? (sim/nao):  sim
# Nao pode dirigir

# %%
numero = int(input("Digite um numero: "))

if numero >= 50 and numero <=100:
    print("Numero esta entre 50 e 100")

else:
    print("Nao esta entre 50 e 100")
# Out:
# Digite um numero:  58
# Numero esta entre 50 e 100

# %%
dia_semana = input (" Digite o dia da semana : ")

if dia_semana == "sabado" or dia_semana == "domingo":
    print ("É final de semana ")
else :
    print ("É dia útil ")
# Out:
#  Digite o dia da semana :  sabado
# É final de semana

# %%
usuario = input("Digite o usuario: ")
senha = input("Digite a senha: ")

if usuario == "Ryan" and senha == "123":
    print("Loguin realizado")

else:
    print("Usuario ou senha invalidos!")
# Out:
# Digite o usuario:  Ryan
# Digite a senha:  123
# Loguin realizado

# %%
nota = int(input("Digite sua nota: "))
frequencia = int(input("Digite sua frequencia: "))

if nota >= 7 and frequencia >= 70:
    print("Aprovado!")

else:
    print("Reprovado!")
# Out:
# Digite sua nota:  7
# Digite sua frequencia:  70
# Aprovado!

# %%
aluno = input("Voce entregou o trabalho? (sim/nao) ")

if not aluno == 'sim':
    print("Voce nao entregou o trabalho!")

else:
    print("Voce entregou o trabalho")
# Out:
# Voce entregou o trabalho? (sim/nao)  nao
# Voce nao entregou o trabalho!

# %% [markdown]
# Exercicios B

# %%
contador = 1

while contador <= 10:
    print ( contador )
contador = contador + 1
