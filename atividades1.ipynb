# %% [markdown]
# Exercício 1
# Crie um programa que mostre na tela:

# %%
a= "Estou aprendendo python"
print(a)
# Out:
# Estou aprendendo python

# %% [markdown]
# Exercício 2
# Crie um programa que mostre:

# %%
nome= "Pamphilly"
cidade="Goiania"
print("Meu nome é",nome)
print("Eu moro em", cidade)
# Out:
# Meu nome é Pamphilly
# Eu moro em Goiania

# %% [markdown]
# Exercício 3
# Crie duas variáveis: nome_do_aluno e idade_do_aluno.
# Depois mostre na tela algo assim:

# %%
nome_do_aluno= "Ryan"
idade_do_aluno= 18
print("Meu nome é",nome_do_aluno, "e tenho",idade_do_aluno, "anos")
# Out:
# Meu nome é Ryan e tenho 18 anos

# %% [markdown]
# Exercício 4 (Desafio Extra)
# Crie três variáveis: cidade, estado e pais. E mostre:

# %%
cidade= "Goiania"
estado= "Go"
pais= "Brasil"
print("Eu moro em", cidade, "-", estado, ",", pais)
# Out:
# Eu moro em Goiania - Go , Brasil

# %% [markdown]
# Crie um programa que:
# 1. Pergunte o nome do aluno.
# 2. Pergunte a cidade onde ele mora.
# 3. Mostre a frase:

# %%
nome_do_aluno= input("Qual o seu nome? ")
cidade_do_aluno= input("Qual cidade voçê mora? ")
print("Seu nome é", nome_do_aluno)
print("Voce mora em ", cidade_do_aluno)
# Out:
# Qual o seu nome?  Ryan
# Qual cidade voçê mora?  Goiania
# Seu nome é Ryan
# Voce mora em  Goiania
